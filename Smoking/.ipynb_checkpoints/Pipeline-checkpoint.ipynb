# %%
import tensorflow_data_validation as tfdv
import tensorflow_transform as tft
import tensorflow_transform.beam as tft_beam
import tensorflow as tf
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
_pipeline_root = 'pipeline'
context = InteractiveContext(pipeline_root=_pipeline_root)
# Out:
# 2023-04-12 15:12:15.415872: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-12 15:12:15.519958: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-12 15:12:15.519978: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-12 15:12:16.076741: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-12 15:12:16.076812: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-12 15:12:16.076820: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at pipeline/metadata.sqlite.

# %%
from tfx.proto import example_gen_pb2
import os
from tfx.components import CsvExampleGen


output= example_gen_pb2.Output(
split_config=example_gen_pb2.SplitConfig(splits=[
    example_gen_pb2.SplitConfig.Split(name='train',hash_buckets=7),
    example_gen_pb2.SplitConfig.Split(name='eval',hash_buckets=3)
    ])   
)

examples_gen = CsvExampleGen(input_base='data',output_config=output)
context.run(examples_gen)
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 28
#     outputs:
#         examples: OutputChannel(artifact_type=Examples, producer_component_id=CsvExampleGen, output_key=examples, additional_properties={}, additional_custom_properties={}))

# %%
from tfx.components import StatisticsGen

statistics_gen = StatisticsGen(
    examples=examples_gen.outputs['examples']
)
context.run(statistics_gen)
# Out:
# ExecutionResult(
#     component_id: StatisticsGen
#     execution_id: 29
#     outputs:
#         statistics: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=StatisticsGen, output_key=statistics, additional_properties={}, additional_custom_properties={}))

# %%
context.show(statistics_gen.outputs['statistics'])
# Out:
# <b>Artifact at pipeline/StatisticsGen/statistics/29</b><br/><br/>
# <style>html[theme=dark] iframe {background: white;}</style>
# <div><b>'train' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'eval' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
from tfx.components import SchemaGen

schema_gen = SchemaGen(
    statistics=statistics_gen.outputs['statistics'],
    infer_feature_shape=True
)
context.run(schema_gen)
# Out:
# ExecutionResult(
#     component_id: SchemaGen
#     execution_id: 30
#     outputs:
#         schema: OutputChannel(artifact_type=Schema, producer_component_id=SchemaGen, output_key=schema, additional_properties={}, additional_custom_properties={}))

# %%
context.show(schema_gen.outputs['schema'])
# Out:
# <b>Artifact at pipeline/SchemaGen/schema/30</b><br/><br/>
#                         Type  Presence Valency Domain
# Feature name
# 'ALT'                    INT  required              -
# 'AST'                    INT  required              -
# 'Cholesterol'            INT  required              -
# 'Gtp'                    INT  required              -
# 'HDL'                    INT  required              -
# 'LDL'                    INT  required              -
# 'Urine protein'          INT  required              -
# 'age'                    INT  required              -
# 'dental caries'          INT  required              -
# 'eyesight(left)'       FLOAT  required              -
# 'eyesight(right)'      FLOAT  required              -
# 'fasting blood sugar'    INT  required              -
# 'hearing(left)'          INT  required              -
# 'hearing(right)'         INT  required              -
# 'height(cm)'             INT  required              -
# 'hemoglobin'           FLOAT  required              -
# 'relaxation'             INT  required              -
# 'serum creatinine'     FLOAT  required              -
# 'smoking'                INT  required              -
# 'systolic'               INT  required              -
# 'triglyceride'           INT  required              -
# 'waist(cm)'            FLOAT  required              -
# 'weight(kg)'             INT  required              -

# %%
from tfx.components import ExampleValidator

example_validator = ExampleValidator(
    statistics=statistics_gen.outputs['statistics'],
    schema=schema_gen.outputs['schema']
)
context.run(example_validator)
# Out:
# ExecutionResult(
#     component_id: ExampleValidator
#     execution_id: 31
#     outputs:
#         anomalies: OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=ExampleValidator, output_key=anomalies, additional_properties={}, additional_custom_properties={}))

# %%
smoking_constants_file = 'smoking_constants.py'

# %%
# %%writefile {smoking_constants_file}
#
# SCALE_TO_Z_SCORE = {'ALT':None,'AST':None,'Cholesterol':None,'Gtp':None,'HDL':None,'LDL':None,'fasting blood sugar':None,'hemoglobin':None,'relaxation':None,'serum creatinine':None,'systolic':None,'triglyceride':None}
# NORMALIZE_TO_0_1 = {'age':None,'height(cm)':None,'waist(cm)':None,'weight(kg)':None}
# CLIP_AFTER = {'hearing(left)':1,'hearing(right)':1,'eyesight(left)':2,'eyesight(right)':2,'Urine protein':1}
# UNCHANGED = {'dental caries':None,'smoking':None}
#
# def transformed_name(key):
#     return key + '_xf'
# Out:
# Overwriting smoking_constants.py

# %%
smoking_transform_file = 'smoking_transform.py'

# %%
# %%writefile {smoking_transform_file}
#
# import tensorflow as tf
# import tensorflow_transform as tft
#
# import smoking_constants
#
# SCALE_TO_Z_SCORE = smoking_constants.SCALE_TO_Z_SCORE
# transformed_name = smoking_constants.transformed_name
# NORMALIZE_TO_0_1 = smoking_constants.NORMALIZE_TO_0_1
# CLIP_AFTER = smoking_constants.CLIP_AFTER
# UNCHANGED = smoking_constants.UNCHANGED
#
#
# def preprocessing_fn(inputs):
#     outputs = {}
#     for key in SCALE_TO_Z_SCORE.keys():
#         key_data = inputs[key]
#         scaled_data = tft.scale_to_z_score(key_data)
#         clipped_data = tf.clip_by_value(scaled_data, -3.0,3.0)
#         outputs[transformed_name(key)] = clipped_data
#
#     for key in NORMALIZE_TO_0_1.keys():
#         key_data2 = inputs[key]
#         scaled_data2 = tft.scale_to_0_1(key_data2)
#         outputs[transformed_name(key)] = scaled_data2
#
#     for key in CLIP_AFTER.keys():
#         key_data3 = inputs[key]
#         clipped_data3 = tf.clip_by_value(key_data3, 0,CLIP_AFTER[key])
#         scaled_data3 = tft.scale_to_0_1(clipped_data3)
#         outputs[transformed_name(key)] = scaled_data3
#
#     for key in UNCHANGED.keys():
#         key_data4 = inputs[key]
#         outputs[transformed_name(key)] = key_data4
#
#     return outputs
# Out:
# Overwriting smoking_transform.py

# %%
import tfx
transform = tfx.components.Transform(
    examples = examples_gen.outputs['examples'],
    schema = schema_gen.outputs['schema'],
    module_file=os.path.abspath(smoking_transform_file)
)
context.run(transform)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying inference.py -> build/lib
# copying smoking_constants.py -> build/lib
# copying smoking_transform.py -> build/lib
# copying smoking_trainer.py -> build/lib
# installing to /tmp/tmpeahld_fk
# running install
# running install_lib
# copying build/lib/smoking_trainer.py -> /tmp/tmpeahld_fk
# copying build/lib/smoking_transform.py -> /tmp/tmpeahld_fk
# copying build/lib/smoking_constants.py -> /tmp/tmpeahld_fk
# copying build/lib/inference.py -> /tmp/tmpeahld_fk
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# /home/thakur/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmpeahld_fk/tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e-py3.9.egg-info
# running install_scripts
# creating /tmp/tmpeahld_fk/tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/WHEEL
# creating '/tmp/tmp_trtk6jl/tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e-py3-none-any.whl' and adding '/tmp/tmpeahld_fk' to it
# adding 'inference.py'
# adding 'smoking_constants.py'
# adding 'smoking_trainer.py'
# adding 'smoking_transform.py'
# adding 'tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/RECORD'
# removing /tmp/tmpeahld_fk
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e
# WARNING:tensorflow:From /home/thakur/anaconda3/lib/python3.9/site-packages/tensorflow_transform/tf_utils.py:324: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# 2023-04-12 15:12:45.457130: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-04-12 15:12:45.457153: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-12 15:12:45.457178: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mako02.fysik.su.se): /proc/driver/nvidia/version does not exist
# 2023-04-12 15:12:45.457356: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/thakur/anaconda3/lib/python3.9/site-packages/tensorflow_transform/tf_utils.py:324: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[<class 'str'>, Union[<class 'NoneType'>, <class 'tfx.components.transform.executor._Dataset'>]], Union[<class 'NoneType'>, Dict[<class 'str'>, Dict[<class 'str'>, <class 'apache_beam.pvalue.PCollection'>]]], <class 'int'>] instead.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[<class 'str'>, Union[<class 'NoneType'>, <class 'tfx.components.transform.executor._Dataset'>]], Union[<class 'NoneType'>, Dict[<class 'str'>, Dict[<class 'str'>, <class 'apache_beam.pvalue.PCollection'>]]], <class 'int'>] instead.
# WARNING:root:This input type hint will be ignored and not used for type-checking purposes. Typically, input type hints for a PTransform are single (or nested) types wrapped by a PCollection, or PBegin. Got: Dict[<class 'tensorflow_transform.beam.analyzer_cache.DatasetKey'>, <class 'tensorflow_transform.beam.analyzer_cache.DatasetCache'>] instead.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: List[<class 'apache_beam.pvalue.PDone'>] instead.
# WARNING:root:This input type hint will be ignored and not used for type-checking purposes. Typically, input type hints for a PTransform are single (or nested) types wrapped by a PCollection, or PBegin. Got: Dict[<class 'tensorflow_transform.beam.analyzer_cache.DatasetKey'>, <class 'tensorflow_transform.beam.analyzer_cache.DatasetCache'>] instead.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: List[<class 'apache_beam.pvalue.PDone'>] instead.
# INFO:tensorflow:Assets written to: pipeline/Transform/transform_graph/32/.temp_path/tftransform_tmp/f0c380673f674c86aeaf128478e13b97/assets
# INFO:tensorflow:Assets written to: pipeline/Transform/transform_graph/32/.temp_path/tftransform_tmp/f0c380673f674c86aeaf128478e13b97/assets
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:Assets written to: pipeline/Transform/transform_graph/32/.temp_path/tftransform_tmp/35e969681fa046b18efb3fb53119e3f8/assets
# INFO:tensorflow:Assets written to: pipeline/Transform/transform_graph/32/.temp_path/tftransform_tmp/35e969681fa046b18efb3fb53119e3f8/assets
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# ExecutionResult(
#     component_id: Transform
#     execution_id: 32
#     outputs:
#         transform_graph: OutputChannel(artifact_type=TransformGraph, producer_component_id=Transform, output_key=transform_graph, additional_properties={}, additional_custom_properties={})
#         transformed_examples: OutputChannel(artifact_type=Examples, producer_component_id=Transform, output_key=transformed_examples, additional_properties={}, additional_custom_properties={})
#         updated_analyzer_cache: OutputChannel(artifact_type=TransformCache, producer_component_id=Transform, output_key=updated_analyzer_cache, additional_properties={}, additional_custom_properties={})
#         pre_transform_schema: OutputChannel(artifact_type=Schema, producer_component_id=Transform, output_key=pre_transform_schema, additional_properties={}, additional_custom_properties={})
#         pre_transform_stats: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=Transform, output_key=pre_transform_stats, additional_properties={}, additional_custom_properties={})
#         post_transform_schema: OutputChannel(artifact_type=Schema, producer_component_id=Transform, output_key=post_transform_schema, additional_properties={}, additional_custom_properties={})
#         post_transform_stats: OutputChannel(artifact_type=ExampleStatistics, producer_component_id=Transform, output_key=post_transform_stats, additional_properties={}, additional_custom_properties={})
#         post_transform_anomalies: OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=Transform, output_key=post_transform_anomalies, additional_properties={}, additional_custom_properties={}))

# %%
trainer_module_file = 'smoking_trainer.py'

# %%
# %%writefile {trainer_module_file}
#
# import tensorflow as tf
# # import tensorflow_decision_forests as tfdf
# import tensorflow_transform as tft
#
# from absl import logging
# from tensorflow.keras import layers, Model, optimizers, losses, metrics
# from tfx import v1 as tfx
# from tfx_bsl.public import tfxio
# from typing import List, Text
# import smoking_constants
# import os
#
# SCALE_TO_Z_SCORE = smoking_constants.SCALE_TO_Z_SCORE
# transformed_name = smoking_constants.transformed_name
# NORMALIZE_TO_0_1 = smoking_constants.NORMALIZE_TO_0_1
# CLIP_AFTER = smoking_constants.CLIP_AFTER
# UNCHANGED = smoking_constants.UNCHANGED
#
# def model_fn():
#     inputs = {}
#     for key,item in SCALE_TO_Z_SCORE.items():
#         inputs[transformed_name(key)] = tf.keras.Input(shape=(1,),name=transformed_name(key))
#
#     for key,item in NORMALIZE_TO_0_1.items():
#         inputs[transformed_name(key)] = tf.keras.Input(shape=(1,),name=transformed_name(key))
#
#     for key,item in CLIP_AFTER.items():
#         inputs[transformed_name(key)] = tf.keras.Input(shape=(1,),name=transformed_name(key))
#
#     inputs['dental caries_xf'] = tf.keras.Input(shape=(1,),name=transformed_name('dental caries'))
#     output = tf.keras.layers.Concatenate()(tf.nest.flatten(inputs))
#     output = tf.keras.layers.BatchNormalization()(output)
#     output = tf.keras.layers.Dense(256, activation='relu')(output)
#     output = tf.keras.layers.Dropout(0.3)(output)
#     output = tf.keras.layers.BatchNormalization()(output)
#     output = tf.keras.layers.Dense(128, activation='relu')(output)
#     output = tf.keras.layers.Dropout(0.3)(output)
#     output = tf.keras.layers.BatchNormalization()(output)
#     output = tf.keras.layers.Dense(32, activation='relu')(output)
#     output = tf.keras.layers.Dropout(0.3)(output)
#     output = tf.keras.layers.BatchNormalization()(output)
#     output = tf.keras.layers.Dense(32, activation='relu')(output)
#     output = tf.keras.layers.Dropout(0.3)(output)
#     output = tf.keras.layers.BatchNormalization()(output)
#     output = tf.keras.layers.Dense(32, activation='relu')(output)
#     output = tf.keras.layers.Dropout(0.3)(output)
#     output = tf.keras.layers.BatchNormalization()(output)
#     output = tf.keras.layers.Dense(32, activation='relu')(output)
#     output = tf.keras.layers.Dropout(0.3)(output)
#     output = tf.keras.layers.BatchNormalization()(output)
#     output = tf.keras.layers.Dense(16, activation='relu')(output)
#     output = tf.keras.layers.Dense(1,activation='sigmoid')(output)
#     model = tf.keras.models.Model(inputs,output)
#
#     # Compile model
#     model.compile(optimizer='adam',#tf.keras.optimizers.Adam(learning_rate=0.01),
#                 loss='binary_crossentropy',#mae
#                 metrics=['binary_accuracy'])
#
#     return model
#
#
#
#
#
# LABEL_KEY = 'smoking_xf'
#
# def _gzip_reader_fn(filenames):
#     return tf.data.TFRecordDataset(filenames,compression_type='GZIP')
#
# def input_fn(file_pattern, tf_transform_output, batch_size=512):
#     transformed_feature_spec = tf_transform_output.transformed_feature_spec().copy()
#     dataset = tf.data.experimental.make_batched_features_dataset(
#         file_pattern=file_pattern,
#         batch_size=batch_size,
#         features=transformed_feature_spec,
#         reader=_gzip_reader_fn,
#         label_key=LABEL_KEY
#     )
#     return dataset
#
# def _get_serve_tf_examples_fn(model, tf_transform_output):
#     """
#     Returns a function that parses a serialized tf.Example and applies
#     the transformations during inference.
#     Args:
#         model: The model that we are serving.
#         tf_transform_output: The transformation output that we want to
#             include with the model.
#     """
#
#     model.tft_layer = tf_transform_output.transform_features_layer()
#
#     @tf.function(input_signature=[tf.TensorSpec(shape=[None], dtype=tf.string, name="examples")])
#     def serve_tf_examples_fn(serialized_tf_examples):
#         feature_spec = tf_transform_output.raw_feature_spec()
#
#         required_feature_spec = {
#             k: v for k, v in feature_spec.items() if k != 'smoking'
#         }
#         print(required_feature_spec)
#         parsed_features = tf.io.parse_example(
#             serialized_tf_examples,
#             required_feature_spec
#         )
#
#         transformed_features = model.tft_layer(parsed_features)
#
#         return model(transformed_features)
#
#     return serve_tf_examples_fn
#
#
#
# def run_fn(fn_args):
#     tf_transform_output = tft.TFTransformOutput(fn_args.transform_output)
#     train_dataset = input_fn(fn_args.train_files,tf_transform_output)
#     eval_dataset = input_fn(fn_args.eval_files,tf_transform_output)
#
#     model = model_fn()
#
#     log_dir = os.path.join(os.path.dirname(fn_args.serving_model_dir),'logs')
#     tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,update_freq='batch')
#
#     model.fit(
#         x=train_dataset,
#         steps_per_epoch = fn_args.train_steps,
#         validation_data = eval_dataset,
#         validation_steps = fn_args.eval_steps,
#         epochs=50,
#         callbacks=[tensorboard_callback]
#     )
#
#     signatures = {
#         'serving_default':
#         _get_serve_tf_examples_fn(model,
#                                  tf_transform_output).get_concrete_function(
#                                     tf.TensorSpec(
#                                     shape=[None],
#                                     dtype=tf.string,
#                                     name='examples')),
#     }
#     model.save(fn_args.serving_model_dir,save_format='tf',signatures=signatures,overwrite=True)#
#     # print("Model saved to:", fn_args.serving_model_dir)
# Out:
# Overwriting smoking_trainer.py

# %%
from tfx.components import Trainer
from tfx.components.base import executor_spec
from tfx.components.trainer.executor import GenericExecutor
from tfx.proto import trainer_pb2
import tensorflow_transform as tft

TRAINING_STEPS = 500
EVALUTION_STEPS = 250

trainer = Trainer(
    module_file=trainer_module_file,
    custom_executor_spec = executor_spec.ExecutorClassSpec(GenericExecutor),
    transform_graph = transform.outputs['transform_graph'],
    transformed_examples = transform.outputs['transformed_examples'],
    schema=schema_gen.outputs['schema'],
    train_args = trainer_pb2.TrainArgs(num_steps=TRAINING_STEPS),
    eval_args = trainer_pb2.EvalArgs(num_steps=EVALUTION_STEPS)
)

context.run(trainer)
# Out:
# WARNING:absl:`custom_executor_spec` is deprecated. Please customize component directly.
# WARNING:absl:`transformed_examples` is deprecated. Please use `examples` instead.
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying inference.py -> build/lib
# copying smoking_constants.py -> build/lib
# copying smoking_transform.py -> build/lib
# copying smoking_trainer.py -> build/lib
# installing to /tmp/tmp8dxgqcu9
# running install
# running install_lib
# copying build/lib/smoking_trainer.py -> /tmp/tmp8dxgqcu9
# copying build/lib/smoking_transform.py -> /tmp/tmp8dxgqcu9
# copying build/lib/smoking_constants.py -> /tmp/tmp8dxgqcu9
# copying build/lib/inference.py -> /tmp/tmp8dxgqcu9
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# /home/thakur/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmp8dxgqcu9/tfx_user_code_Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e-py3.9.egg-info
# running install_scripts
# creating /tmp/tmp8dxgqcu9/tfx_user_code_Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/WHEEL
# creating '/tmp/tmp99tkurm0/tfx_user_code_Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e-py3-none-any.whl' and adding '/tmp/tmp8dxgqcu9' to it
# adding 'inference.py'
# adding 'smoking_constants.py'
# adding 'smoking_trainer.py'
# adding 'smoking_transform.py'
# adding 'tfx_user_code_Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e.dist-info/RECORD'
# removing /tmp/tmp8dxgqcu9
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# Processing ./pipeline/_wheels/tfx_user_code_Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e-py3-none-any.whl
# Installing collected packages: tfx-user-code-Trainer
# Successfully installed tfx-user-code-Trainer-0.0+fb5bbf0b8a67bc5a4a9548448f53451efb510d5a099112b2138fbdf33807190e
# Epoch 1/50
# 500/500 [==============================] - 6s 8ms/step - loss: 0.5439 - binary_accuracy: 0.7025 - val_loss: 0.4853 - val_binary_accuracy: 0.7457
# Epoch 2/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4908 - binary_accuracy: 0.7413 - val_loss: 0.4780 - val_binary_accuracy: 0.7530
# Epoch 3/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4796 - binary_accuracy: 0.7513 - val_loss: 0.4782 - val_binary_accuracy: 0.7551
# Epoch 4/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4716 - binary_accuracy: 0.7580 - val_loss: 0.4756 - val_binary_accuracy: 0.7552
# Epoch 5/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4641 - binary_accuracy: 0.7641 - val_loss: 0.4795 - val_binary_accuracy: 0.7498
# Epoch 6/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4573 - binary_accuracy: 0.7691 - val_loss: 0.4815 - val_binary_accuracy: 0.7502
# Epoch 7/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4499 - binary_accuracy: 0.7745 - val_loss: 0.4914 - val_binary_accuracy: 0.7430
# Epoch 8/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4429 - binary_accuracy: 0.7805 - val_loss: 0.4985 - val_binary_accuracy: 0.7458
# Epoch 9/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4351 - binary_accuracy: 0.7870 - val_loss: 0.4916 - val_binary_accuracy: 0.7429
# Epoch 10/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.4287 - binary_accuracy: 0.7917 - val_loss: 0.5030 - val_binary_accuracy: 0.7401
# Epoch 11/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4215 - binary_accuracy: 0.7968 - val_loss: 0.5000 - val_binary_accuracy: 0.7443
# Epoch 12/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.4146 - binary_accuracy: 0.8024 - val_loss: 0.5033 - val_binary_accuracy: 0.7407
# Epoch 13/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4074 - binary_accuracy: 0.8073 - val_loss: 0.5204 - val_binary_accuracy: 0.7369
# Epoch 14/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.4027 - binary_accuracy: 0.8116 - val_loss: 0.5184 - val_binary_accuracy: 0.7344
# Epoch 15/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3986 - binary_accuracy: 0.8141 - val_loss: 0.5058 - val_binary_accuracy: 0.7375
# Epoch 16/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3928 - binary_accuracy: 0.8165 - val_loss: 0.5234 - val_binary_accuracy: 0.7315
# Epoch 17/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3886 - binary_accuracy: 0.8206 - val_loss: 0.5224 - val_binary_accuracy: 0.7287
# Epoch 18/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3856 - binary_accuracy: 0.8217 - val_loss: 0.5322 - val_binary_accuracy: 0.7317
# Epoch 19/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3812 - binary_accuracy: 0.8246 - val_loss: 0.5414 - val_binary_accuracy: 0.7293
# Epoch 20/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3774 - binary_accuracy: 0.8274 - val_loss: 0.5252 - val_binary_accuracy: 0.7272
# Epoch 21/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.3735 - binary_accuracy: 0.8297 - val_loss: 0.5393 - val_binary_accuracy: 0.7301
# Epoch 22/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3707 - binary_accuracy: 0.8311 - val_loss: 0.5489 - val_binary_accuracy: 0.7322
# Epoch 23/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3694 - binary_accuracy: 0.8317 - val_loss: 0.5482 - val_binary_accuracy: 0.7237
# Epoch 24/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3661 - binary_accuracy: 0.8346 - val_loss: 0.5284 - val_binary_accuracy: 0.7261
# Epoch 25/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3631 - binary_accuracy: 0.8356 - val_loss: 0.5480 - val_binary_accuracy: 0.7286
# Epoch 26/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.3627 - binary_accuracy: 0.8362 - val_loss: 0.5561 - val_binary_accuracy: 0.7210
# Epoch 27/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3586 - binary_accuracy: 0.8387 - val_loss: 0.5436 - val_binary_accuracy: 0.7278
# Epoch 28/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3584 - binary_accuracy: 0.8391 - val_loss: 0.5553 - val_binary_accuracy: 0.7250
# Epoch 29/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.3556 - binary_accuracy: 0.8401 - val_loss: 0.5513 - val_binary_accuracy: 0.7238
# Epoch 30/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3531 - binary_accuracy: 0.8413 - val_loss: 0.5332 - val_binary_accuracy: 0.7272
# Epoch 31/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.3523 - binary_accuracy: 0.8428 - val_loss: 0.5755 - val_binary_accuracy: 0.7210
# Epoch 32/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3493 - binary_accuracy: 0.8435 - val_loss: 0.5608 - val_binary_accuracy: 0.7252
# Epoch 33/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3471 - binary_accuracy: 0.8452 - val_loss: 0.5562 - val_binary_accuracy: 0.7225
# Epoch 34/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3473 - binary_accuracy: 0.8456 - val_loss: 0.5590 - val_binary_accuracy: 0.7296
# Epoch 35/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3456 - binary_accuracy: 0.8462 - val_loss: 0.5682 - val_binary_accuracy: 0.7241
# Epoch 36/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.3436 - binary_accuracy: 0.8473 - val_loss: 0.5655 - val_binary_accuracy: 0.7251
# Epoch 37/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3417 - binary_accuracy: 0.8482 - val_loss: 0.5553 - val_binary_accuracy: 0.7243
# Epoch 38/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3404 - binary_accuracy: 0.8482 - val_loss: 0.5564 - val_binary_accuracy: 0.7242
# Epoch 39/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3392 - binary_accuracy: 0.8496 - val_loss: 0.5591 - val_binary_accuracy: 0.7228
# Epoch 40/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3394 - binary_accuracy: 0.8490 - val_loss: 0.5651 - val_binary_accuracy: 0.7275
# Epoch 41/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3368 - binary_accuracy: 0.8507 - val_loss: 0.5595 - val_binary_accuracy: 0.7258
# Epoch 42/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3361 - binary_accuracy: 0.8506 - val_loss: 0.5625 - val_binary_accuracy: 0.7224
# Epoch 43/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3342 - binary_accuracy: 0.8525 - val_loss: 0.5680 - val_binary_accuracy: 0.7252
# Epoch 44/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3351 - binary_accuracy: 0.8523 - val_loss: 0.5664 - val_binary_accuracy: 0.7235
# Epoch 45/50
# 500/500 [==============================] - 5s 10ms/step - loss: 0.3324 - binary_accuracy: 0.8534 - val_loss: 0.5630 - val_binary_accuracy: 0.7218
# Epoch 46/50
# 500/500 [==============================] - 4s 9ms/step - loss: 0.3311 - binary_accuracy: 0.8548 - val_loss: 0.5827 - val_binary_accuracy: 0.7218
# Epoch 47/50
# 500/500 [==============================] - 5s 9ms/step - loss: 0.3302 - binary_accuracy: 0.8547 - val_loss: 0.5736 - val_binary_accuracy: 0.7207
# Epoch 48/50
# 500/500 [==============================] - 6s 11ms/step - loss: 0.3305 - binary_accuracy: 0.8546 - val_loss: 0.5741 - val_binary_accuracy: 0.7187
# Epoch 49/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3289 - binary_accuracy: 0.8549 - val_loss: 0.5825 - val_binary_accuracy: 0.7164
# Epoch 50/50
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3294 - binary_accuracy: 0.8554 - val_loss: 0.5785 - val_binary_accuracy: 0.7175
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# WARNING:tensorflow:From /home/thakur/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/thakur/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# {'ALT': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'AST': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'Cholesterol': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'Gtp': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'HDL': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'LDL': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'Urine protein': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'age': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'dental caries': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'eyesight(left)': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'eyesight(right)': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'fasting blood sugar': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'hearing(left)': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'hearing(right)': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'height(cm)': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'hemoglobin': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'relaxation': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'serum creatinine': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'systolic': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'triglyceride': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'waist(cm)': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'weight(kg)': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None)}
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`Urine protein_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`dental caries_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`eyesight(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`fasting blood sugar_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(left)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`hearing(right)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`height(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`serum creatinine_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`waist(cm)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:tensorflow:`weight(kg)_xf` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: pipeline/Trainer/model/33/Format-Serving/assets
# INFO:tensorflow:Assets written to: pipeline/Trainer/model/33/Format-Serving/assets
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 33
#     outputs:
#         model: OutputChannel(artifact_type=Model, producer_component_id=Trainer, output_key=model, additional_properties={}, additional_custom_properties={})
#         model_run: OutputChannel(artifact_type=ModelRun, producer_component_id=Trainer, output_key=model_run, additional_properties={}, additional_custom_properties={}))

# %%
model_path = trainer.outputs['model'].get()[0].uri

# %%
# %reload_ext tensorboard
# %tensorboard --logdir {model_path}
# Out:
#       <iframe id="tensorboard-frame-491bce5206810f2c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-491bce5206810f2c");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import tensorflow_model_analysis as tfma
eval_shared_model = tfma.default_eval_shared_model(
    eval_saved_model_path=model_path,
    tags=[tf.saved_model.SERVING]
)

eval_config = tfma.EvalConfig(
    model_specs=[tfma.ModelSpec(label_key='smoking')],
    slicing_specs=[tfma.SlicingSpec()],
    metrics_specs=[
    tfma.MetricsSpec(metrics=[
    tfma.MetricConfig(class_name='BinaryAccuracy'),
    tfma.MetricConfig(class_name='ExampleCount'),
    tfma.MetricConfig(class_name='FalsePositives'),
    tfma.MetricConfig(class_name='TruePositives'),
    tfma.MetricConfig(class_name='FalseNegatives'),
    tfma.MetricConfig(class_name='TrueNegatives'),
    tfma.MetricConfig(class_name='Precision'),
    tfma.MetricConfig(class_name='Recall')
    ])
    ]
)

from tfx.components import Evaluator

evaluator = Evaluator(
     examples=examples_gen.outputs['examples'],
     model=trainer.outputs['model'],
     eval_config=eval_config)

context.run(evaluator, enable_cache=True)
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdffcf8dc70> and <keras.engine.input_layer.InputLayer object at 0x7fdffd1d4bb0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdffcf8dc70> and <keras.engine.input_layer.InputLayer object at 0x7fdffd1d4bb0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe71bd790> and <keras.engine.input_layer.InputLayer object at 0x7fdfe714c4f0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe71bd790> and <keras.engine.input_layer.InputLayer object at 0x7fdfe714c4f0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fe0376bbac0> and <keras.engine.input_layer.InputLayer object at 0x7fdffdff4280>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fe0376bbac0> and <keras.engine.input_layer.InputLayer object at 0x7fdffdff4280>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe6ae1fd0> and <keras.engine.input_layer.InputLayer object at 0x7fdfe69dca00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe6ae1fd0> and <keras.engine.input_layer.InputLayer object at 0x7fdfe69dca00>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe6933e20> and <keras.engine.input_layer.InputLayer object at 0x7fdfe78af850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe6933e20> and <keras.engine.input_layer.InputLayer object at 0x7fdfe78af850>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe5dbddc0> and <keras.engine.input_layer.InputLayer object at 0x7fdfe5f22820>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe5dbddc0> and <keras.engine.input_layer.InputLayer object at 0x7fdfe5f22820>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe42181c0> and <keras.engine.input_layer.InputLayer object at 0x7fdfe428d550>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfe42181c0> and <keras.engine.input_layer.InputLayer object at 0x7fdfe428d550>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfdafa78e0> and <keras.engine.input_layer.InputLayer object at 0x7fdfe4251a90>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.legacy.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fdfdafa78e0> and <keras.engine.input_layer.InputLayer object at 0x7fdfe4251a90>).
# ExecutionResult(
#     component_id: Evaluator
#     execution_id: 34
#     outputs:
#         evaluation: OutputChannel(artifact_type=ModelEvaluation, producer_component_id=Evaluator, output_key=evaluation, additional_properties={}, additional_custom_properties={})
#         blessing: OutputChannel(artifact_type=ModelBlessing, producer_component_id=Evaluator, output_key=blessing, additional_properties={}, additional_custom_properties={}))

# %%
eval_results = evaluator.outputs['evaluation'].get()[0].uri
tfma_results = tfma.load_eval_result(eval_results)
# Out:
# WARNING:tensorflow:From /home/thakur/anaconda3/lib/python3.9/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/thakur/anaconda3/lib/python3.9/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
tfma.view.render_slicing_metrics(tfma_results)
# Out:
# SlicingMetricsViewer(config={'weightedExamplesColumn': 'example_count'}, data=[{'slice': 'Overall', 'metrics':…

# %%
eval_results = evaluator.outputs['evaluation'].get()[0].uri
tfma_results = tfma.load_eval_result(eval_results)

tfma.view.render_slicing_metrics(tfma_results)

from tfx.components import Pusher
from tfx.proto import pusher_pb2

_serving_model_dir = 'Serve/model'

pusher = Pusher(
    model = trainer.outputs['model'],
#     model_blessing = evaluator.outputs['blessing'],
    push_destination = pusher_pb2.PushDestination(
    filesystem=pusher_pb2.PushDestination.Filesystem(
    base_directory=_serving_model_dir
    )
))
context.run(pusher)
# Out:
# WARNING:absl:Pusher is going to push the model without validation. Consider using Evaluator or InfraValidator in your pipeline.
# ExecutionResult(
#     component_id: Pusher
#     execution_id: 35
#     outputs:
#         pushed_model: OutputChannel(artifact_type=PushedModel, producer_component_id=Pusher, output_key=pushed_model, additional_properties={}, additional_custom_properties={}))

# %%
blessing_uri = evaluator.outputs['blessing'].get()[0].uri
# !ls -l {blessing_uri}
# Out:
# total 0

# %%
PATH_TO_RESULT = evaluator.outputs['evaluation'].get()[0].uri
print(tfma.load_validation_result(PATH_TO_RESULT))
# Out:
# missing_thresholds: true

# %%
evaluator.outputs
# Out:
# {'evaluation': OutputChannel(artifact_type=ModelEvaluation, producer_component_id=Evaluator, output_key=evaluation, additional_properties={}, additional_custom_properties={}),
#  'blessing': OutputChannel(artifact_type=ModelBlessing, producer_component_id=Evaluator, output_key=blessing, additional_properties={}, additional_custom_properties={})}

# %%
pusher.outputs
# Out:
# {'pushed_model': OutputChannel(artifact_type=PushedModel, producer_component_id=Pusher, output_key=pushed_model, additional_properties={}, additional_custom_properties={})}

# %%
# push_uri = pusher.outputs['pushed_model'].get()[0].uri
# model = tf.saved_model.load(push_uri)

# for item in model.signatures.items():
#   pp.pprint(item)

# %%
import requests
import json
import base64
# The URL of the prediction endpoint
url = 'http://localhost:8501/v1/models/6:predict'

def _float_feature(value):
    return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))
def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

example = tf.train.Example(features=tf.train.Features(feature={
'ALT': _int64_feature(0),
'AST': _int64_feature(0),
'Cholesterol': _int64_feature(0),
'Gtp': _int64_feature(0),
'HDL': _int64_feature(0),
'LDL': _int64_feature(0),
'fasting blood sugar': _int64_feature(0),
'hemoglobin': _float_feature(0),
'relaxation': _int64_feature(0),
'serum creatinine': _float_feature(0),
'systolic': _int64_feature(0),
'triglyceride': _int64_feature(0),
'age': _int64_feature(0),
'height(cm)': _int64_feature(0),
'waist(cm)': _float_feature(0),
'weight(kg)': _int64_feature(0),
'hearing(left)': _int64_feature(0),
'hearing(right)': _int64_feature(0),
'eyesight(left)': _float_feature(0),
'eyesight(right)': _float_feature(0),
'Urine protein': _int64_feature(0),
'dental caries': _int64_feature(0)
}))
serialized_example = example.SerializeToString()

example_bytes = base64.b64encode(serialized_example).decode('utf-8')
payload = {
    'signature_name': 'serving_default',
    'instances': [{
        'b64': example_bytes
    }]
}
response = requests.post(url, json=payload)

# Get the prediction results
prediction_results = json.loads(response.text)
print(round(prediction_results['predictions'][0][0]))
# Out:
# 0
